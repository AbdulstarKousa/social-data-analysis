# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Pick the filename of the dataset to import in pandas
fileName = 'Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv'

filePath = os.path.abspath(os.path.join(os.getcwd(),'Datasets', fileName))
df = pd.read_csv(filePath)

# %%
df
# Out:
#                    PdId  IncidntNum  Incident Code        Category  \
# 0         4018830907041    40188309           7041   VEHICLE THEFT
# 1        13605159706372   136051597           6372   LARCENY/THEFT
# 2        13618826906244   136188269           6244   LARCENY/THEFT
# 3         4098938926105    40989389          26105  OTHER OFFENSES
# 4         5085058207021    50850582           7021   VEHICLE THEFT
# ...                 ...         ...            ...             ...
# 2160948  16054122161030   160541221          61030    NON-CRIMINAL
# 2160949  17044968764085   170449687          64085  SUSPICIOUS OCC
# 2160950  17047243406133   170472434           6133   LARCENY/THEFT
# 2160951  17095059363010   170950593          63010        WARRANTS
# 2160952  17608386706244   176083867           6244   LARCENY/THEFT
#
#                              Descript  DayOfWeek        Date   Time  \
# 0            VEHICLE, RECOVERED, AUTO     Sunday  02/15/2004  02:00
# 1             PETTY THEFT OF PROPERTY   Thursday  03/14/2013  09:21
# 2        GRAND THEFT FROM LOCKED AUTO    Tuesday  10/08/2013  19:30
# 3                FALSE REPORT OF BOMB     Sunday  08/29/2004  22:47
# 4                   STOLEN AUTOMOBILE     Friday  07/29/2005  21:00
# ...                               ...        ...         ...    ...
# 2160948   DEATH REPORT, CAUSE UNKNOWN     Monday  07/04/2016  16:08
# 2160949       INVESTIGATIVE DETENTION   Thursday  06/01/2017  18:42
# 2160950       GRAND THEFT PURSESNATCH     Friday  06/09/2017  19:10
# 2160951                WARRANT ARREST  Wednesday  11/22/2017  14:30
# 2160952  GRAND THEFT FROM LOCKED AUTO  Wednesday  03/22/2017  05:29
#
#          PdDistrict      Resolution  ... Fix It Zones as of 2017-11-06  2 2  \
# 0          SOUTHERN            NONE  ...                                NaN
# 1          SOUTHERN            NONE  ...                                NaN
# 2           MISSION            NONE  ...                                NaN
# 3              PARK            NONE  ...                                NaN
# 4         INGLESIDE            NONE  ...                                NaN
# ...             ...             ...  ...                                ...
# 2160948  TENDERLOIN            NONE  ...                               18.0
# 2160949     BAYVIEW            NONE  ...                                NaN
# 2160950    NORTHERN            NONE  ...                                NaN
# 2160951     MISSION  ARREST, BOOKED  ...                               15.0
# 2160952   INGLESIDE            NONE  ...                                NaN
#
#          DELETE - HSOC Zones 2 2  Fix It Zones as of 2018-02-07 2 2  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            3.0                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
# ...                          ...                                ...
# 2160948                      NaN                               18.0
# 2160949                      NaN                                NaN
# 2160950                      1.0                                NaN
# 2160951                      3.0                               15.0
# 2160952                      NaN                                NaN
#
#         CBD, BID and GBD Boundaries as of 2017 2 2  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2160948                                        6.0
# 2160949                                        NaN
# 2160950                                        NaN
# 2160951                                        NaN
# 2160952                                        NaN
#
#          Areas of Vulnerability, 2016 2 2  \
# 0                                     NaN
# 1                                     2.0
# 2                                     2.0
# 3                                     1.0
# 4                                     2.0
# ...                                   ...
# 2160948                               2.0
# 2160949                               2.0
# 2160950                               1.0
# 2160951                               2.0
# 2160952                               1.0
#
#          Central Market/Tenderloin Boundary 2 2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2160948                                     1.0
# 2160949                                     NaN
# 2160950                                     NaN
# 2160951                                     NaN
# 2160952                                     NaN
#
#          Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 2160948                                                1.0
# 2160949                                                NaN
# 2160950                                                NaN
# 2160951                                                NaN
# 2160952                                                NaN
#
#          HSOC Zones as of 2018-06-05 2 2  OWED Public Spaces 2 2  \
# 0                                    NaN                     NaN
# 1                                    NaN                     NaN
# 2                                    3.0                     NaN
# 3                                    NaN                     NaN
# 4                                    NaN                     NaN
# ...                                  ...                     ...
# 2160948                              NaN                     NaN
# 2160949                              NaN                     NaN
# 2160950                              1.0                     NaN
# 2160951                              3.0                     NaN
# 2160952                              NaN                     NaN
#
#          Neighborhoods 2
# 0                    NaN
# 1                   32.0
# 2                    NaN
# 3                   49.0
# 4                   66.0
# ...                  ...
# 2160948             20.0
# 2160949             86.0
# 2160950             22.0
# 2160951             53.0
# 2160952             83.0
#
# [2160953 rows x 35 columns]

# %% [markdown]
# Simple Statistics
# - Report the total number of crimes in the dataset

# %%
df['PdId'].count()
# Out:
# 2160953

# %% [markdown]
# There are 2,160,953 million crimes recorded from 2013 to May of 2018.
#
# - List the various categories of the crimes

# %%
df['Category'].unique()

# print(len(df['Category'].unique())) There are 38 different crimes

# index = list(df.groupby(by='Category').count().index)
# index
# Out:
# array(['VEHICLE THEFT', 'LARCENY/THEFT', 'OTHER OFFENSES', 'FRAUD',
#        'SEX OFFENSES, FORCIBLE', 'ASSAULT', 'NON-CRIMINAL', 'BURGLARY',
#        'LOITERING', 'ROBBERY', 'SUSPICIOUS OCC', 'FORGERY/COUNTERFEITING',
#        'DRUG/NARCOTIC', 'TRESPASS', 'VANDALISM', 'WARRANTS',
#        'SECONDARY CODES', 'WEAPON LAWS', 'MISSING PERSON', 'DRUNKENNESS',
#        'STOLEN PROPERTY', 'RECOVERED VEHICLE', 'PROSTITUTION', 'ARSON',
#        'EMBEZZLEMENT', 'LIQUOR LAWS', 'DISORDERLY CONDUCT',
#        'DRIVING UNDER THE INFLUENCE', 'KIDNAPPING', 'SUICIDE', 'BRIBERY',
#        'FAMILY OFFENSES', 'SEX OFFENSES, NON FORCIBLE', 'BAD CHECKS',
#        'GAMBLING', 'EXTORTION', 'PORNOGRAPHY/OBSCENE MAT', 'TREA'],
#       dtype=object)

# %% [markdown]
# - List the number of crimes in each category

# %%
crimes = df.groupby(by='Category').PdId.count().sort_values(ascending=False)
crimes
# Out:
# Category
# LARCENY/THEFT                  477975
# OTHER OFFENSES                 303027
# NON-CRIMINAL                   236937
# ASSAULT                        191384
# VEHICLE THEFT                  126228
# DRUG/NARCOTIC                  117875
# VANDALISM                      114718
# WARRANTS                        99821
# BURGLARY                        91067
# SUSPICIOUS OCC                  79740
# ROBBERY                         54467
# MISSING PERSON                  44268
# FRAUD                           41348
# FORGERY/COUNTERFEITING          22995
# SECONDARY CODES                 22378
# WEAPON LAWS                     21004
# TRESPASS                        19194
# PROSTITUTION                    16501
# STOLEN PROPERTY                 11450
# SEX OFFENSES, FORCIBLE          10876
# DISORDERLY CONDUCT               9932
# DRUNKENNESS                      9760
# RECOVERED VEHICLE                8688
# DRIVING UNDER THE INFLUENCE      5652
# KIDNAPPING                       4966
# LIQUOR LAWS                      3941
# ARSON                            3875
# EMBEZZLEMENT                     2984
# LOITERING                        2402
# SUICIDE                          1291
# FAMILY OFFENSES                   926
# BAD CHECKS                        924
# BRIBERY                           796
# EXTORTION                         729
# SEX OFFENSES, NON FORCIBLE        420
# GAMBLING                          343
# PORNOGRAPHY/OBSCENE MAT            57
# TREA                               14
# Name: PdId, dtype: int64

# %% [markdown]
# - **Exercise: The types of crime and their popularity over time. The first field we'll dig into is the column "Category".**

# %%
fig, ax = plt.subplots(figsize=(16, 8))
crimes.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# - Now it's time to explore how the crime statistics change over time. To start off easily, let's count the number of crimes per year for the years 2003-2017 (since we don't have full data for 2018). What's the average number of crimes per year?

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
per = df.Date.dt.to_period("Y")
peryear = df.groupby(per).count()[:-1]
peryear
# Out:
#         PdId  IncidntNum  Incident Code  Category  Descript  DayOfWeek  \
# Date
# 2003  145073      145073         145073    145073    145073     145073
# 2004  144323      144323         144323    144323    144323     144323
# 2005  138807      138807         138807    138807    138807     138807
# 2006  133726      133726         133726    133726    133726     133726
# 2007  133601      133601         133601    133601    133601     133601
# 2008  137113      137113         137113    137113    137113     137113
# 2009  136218      136218         136218    136218    136218     136218
# 2010  129750      129750         129750    129750    129750     129750
# 2011  128563      128563         128563    128563    128563     128563
# 2012  137334      137334         137334    137334    137334     137334
# 2013  149639      149639         149639    149639    149639     149639
# 2014  147056      147056         147056    147056    147056     147056
# 2015  153771      153771         153771    153771    153771     153771
# 2016  148379      148379         148379    148379    148379     148379
# 2017  151759      151759         151759    151759    151759     151759
#
#         Date    Time  PdDistrict  Resolution  ...  \
# Date                                          ...
# 2003  145073  145073      145073      145073  ...
# 2004  144323  144323      144323      144323  ...
# 2005  138807  138807      138807      138807  ...
# 2006  133726  133726      133726      133726  ...
# 2007  133601  133601      133601      133601  ...
# 2008  137113  137113      137113      137113  ...
# 2009  136218  136218      136218      136218  ...
# 2010  129750  129750      129750      129750  ...
# 2011  128563  128563      128563      128563  ...
# 2012  137334  137334      137334      137334  ...
# 2013  149639  149639      149639      149639  ...
# 2014  147056  147056      147056      147056  ...
# 2015  153771  153771      153771      153771  ...
# 2016  148379  148379      148378      148379  ...
# 2017  151759  151759      151759      151759  ...
#
#       Fix It Zones as of 2017-11-06  2 2  DELETE - HSOC Zones 2 2  \
# Date
# 2003                               36650                    31776
# 2004                               35912                    30436
# 2005                               33367                    27949
# 2006                               34090                    28445
# 2007                               36947                    30010
# 2008                               38712                    31835
# 2009                               40438                    31817
# 2010                               35917                    29132
# 2011                               34690                    28440
# 2012                               34598                    28765
# 2013                               39202                    32804
# 2014                               36931                    30411
# 2015                               36111                    30507
# 2016                               34535                    31089
# 2017                               33798                    31906
#
#       Fix It Zones as of 2018-02-07 2 2  \
# Date
# 2003                              37002
# 2004                              36302
# 2005                              33803
# 2006                              34383
# 2007                              37340
# 2008                              39132
# 2009                              40695
# 2010                              36160
# 2011                              34830
# 2012                              34744
# 2013                              39902
# 2014                              37227
# 2015                              36500
# 2016                              34863
# 2017                              34437
#
#       CBD, BID and GBD Boundaries as of 2017 2 2  \
# Date
# 2003                                       37044
# 2004                                       35636
# 2005                                       33049
# 2006                                       33285
# 2007                                       36027
# 2008                                       38340
# 2009                                       39480
# 2010                                       35963
# 2011                                       34851
# 2012                                       35083
# 2013                                       39409
# 2014                                       37993
# 2015                                       37805
# 2016                                       36877
# 2017                                       35857
#
#       Areas of Vulnerability, 2016 2 2  \
# Date
# 2003                            144969
# 2004                            144205
# 2005                            138679
# 2006                            133671
# 2007                            133564
# 2008                            137044
# 2009                            136145
# 2010                            129696
# 2011                            128488
# 2012                            137276
# 2013                            149592
# 2014                            147003
# 2015                            153692
# 2016                            148341
# 2017                            151725
#
#       Central Market/Tenderloin Boundary 2 2  \
# Date
# 2003                                   22905
# 2004                                   22029
# 2005                                   20386
# 2006                                   20696
# 2007                                   23890
# 2008                                   25817
# 2009                                   26890
# 2010                                   22904
# 2011                                   21225
# 2012                                   20640
# 2013                                   23553
# 2014                                   20864
# 2015                                   20478
# 2016                                   19939
# 2017                                   19027
#
#       Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# Date
# 2003                                              22890
# 2004                                              22111
# 2005                                              20399
# 2006                                              20738
# 2007                                              23779
# 2008                                              25715
# 2009                                              26797
# 2010                                              22851
# 2011                                              21092
# 2012                                              20572
# 2013                                              23520
# 2014                                              20949
# 2015                                              20624
# 2016                                              20111
# 2017                                              19224
#
#       HSOC Zones as of 2018-06-05 2 2  OWED Public Spaces 2 2  Neighborhoods 2
# Date
# 2003                            33666                    8042           144631
# 2004                            32224                    7338           143888
# 2005                            29835                    6221           138298
# 2006                            30176                    6873           133367
# 2007                            31576                    7609           133225
# 2008                            33455                    7737           136734
# 2009                            33372                    8158           135842
# 2010                            30621                    6795           129434
# 2011                            30035                    6692           128257
# 2012                            30803                    6975           137009
# 2013                            35208                    8617           149224
# 2014                            32386                    8380           146655
# 2015                            32504                    8704           153307
# 2016                            33166                    8074           147974
# 2017                            34480                    8044           151392
#
# [15 rows x 35 columns]

# %%
print('The average number of crimes per year is:', peryear.PdId.mean())
# Out:
# The average number of crimes per year is: 141007.46666666667

# %%
# df.groupby([per, 'Category']).count()

# %% [markdown]
# - Focus crimes

# %%
df['Year'] = df.Date.dt.to_period("Y")

# %%
index_names = df[df['Year'] == '2018'].index 
#print(index_names)
# drop these given row 
# indexes from dataFrame 
df.drop(index_names, inplace = True)

# %%
# df2 = df[df.Year != 2018]

# %%
df.groupby(['Category', 'Year']).count()
# Out:
#                   PdId  IncidntNum  Incident Code  Descript  DayOfWeek  Date  \
# Category    Year
# ARSON       2003   286         286            286       286        286   286
#             2004   274         274            274       274        274   274
#             2005   229         229            229       229        229   229
#             2006   240         240            240       240        240   240
#             2007   241         241            241       241        241   241
# ...                ...         ...            ...       ...        ...   ...
# WEAPON LAWS 2013  1435        1435           1435      1435       1435  1435
#             2014  1478        1478           1478      1478       1478  1478
#             2015  1590        1590           1590      1590       1590  1590
#             2016  1591        1591           1591      1591       1591  1591
#             2017  1644        1644           1644      1644       1644  1644
#
#                   Time  PdDistrict  Resolution  Address  ...  \
# Category    Year                                         ...
# ARSON       2003   286         286         286      286  ...
#             2004   274         274         274      274  ...
#             2005   229         229         229      229  ...
#             2006   240         240         240      240  ...
#             2007   241         241         241      241  ...
# ...                ...         ...         ...      ...  ...
# WEAPON LAWS 2013  1435        1435        1435     1435  ...
#             2014  1478        1478        1478     1478  ...
#             2015  1590        1590        1590     1590  ...
#             2016  1591        1591        1591     1591  ...
#             2017  1644        1644        1644     1644  ...
#
#                   Fix It Zones as of 2017-11-06  2 2  DELETE - HSOC Zones 2 2  \
# Category    Year
# ARSON       2003                                  37                       26
#             2004                                  29                       30
#             2005                                  23                       29
#             2006                                  43                       29
#             2007                                  33                       24
# ...                                              ...                      ...
# WEAPON LAWS 2013                                 452                      405
#             2014                                 405                      404
#             2015                                 496                      482
#             2016                                 433                      438
#             2017                                 453                      458
#
#                   Fix It Zones as of 2018-02-07 2 2  \
# Category    Year
# ARSON       2003                                 40
#             2004                                 32
#             2005                                 25
#             2006                                 45
#             2007                                 33
# ...                                             ...
# WEAPON LAWS 2013                                458
#             2014                                412
#             2015                                502
#             2016                                447
#             2017                                461
#
#                   CBD, BID and GBD Boundaries as of 2017 2 2  \
# Category    Year
# ARSON       2003                                          20
#             2004                                          35
#             2005                                          25
#             2006                                          28
#             2007                                          27
# ...                                                      ...
# WEAPON LAWS 2013                                         338
#             2014                                         357
#             2015                                         370
#             2016                                         394
#             2017                                         403
#
#                   Areas of Vulnerability, 2016 2 2  \
# Category    Year
# ARSON       2003                               286
#             2004                               273
#             2005                               229
#             2006                               240
#             2007                               241
# ...                                            ...
# WEAPON LAWS 2013                              1432
#             2014                              1478
#             2015                              1585
#             2016                              1591
#             2017                              1643
#
#                   Central Market/Tenderloin Boundary 2 2  \
# Category    Year
# ARSON       2003                                      13
#             2004                                      23
#             2005                                      12
#             2006                                      20
#             2007                                      13
# ...                                                  ...
# WEAPON LAWS 2013                                     285
#             2014                                     277
#             2015                                     283
#             2016                                     258
#             2017                                     302
#
#                   Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# Category    Year
# ARSON       2003                                                 13
#             2004                                                 23
#             2005                                                 12
#             2006                                                 20
#             2007                                                 13
# ...                                                             ...
# WEAPON LAWS 2013                                                284
#             2014                                                276
#             2015                                                283
#             2016                                                261
#             2017                                                304
#
#                   HSOC Zones as of 2018-06-05 2 2  OWED Public Spaces 2 2  \
# Category    Year
# ARSON       2003                               32                       6
#             2004                               30                       0
#             2005                               32                       2
#             2006                               31                       2
#             2007                               27                       2
# ...                                           ...                     ...
# WEAPON LAWS 2013                              431                      90
#             2014                              422                      99
#             2015                              500                      82
#             2016                              456                      97
#             2017                              481                     108
#
#                   Neighborhoods 2
# Category    Year
# ARSON       2003              286
#             2004              274
#             2005              229
#             2006              240
#             2007              241
# ...                           ...
# WEAPON LAWS 2013             1428
#             2014             1475
#             2015             1584
#             2016             1589
#             2017             1639
#
# [557 rows x 34 columns]

# %%
(df.groupby(['Category', 'Year']).count()
 .filter(like = 'VANDALISM', axis=0)['PdId']
 .unstack(level=0)
 .plot(kind='bar', figsize=(9,5), rot=0))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
focuscrimes = set(['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT', 'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT'])

# %%
fig, axarr = plt.subplots(7, 2, figsize=(17, 20), sharex=True)
plt.suptitle('Year by year development of specific focus crimes', fontsize=30)

for i,crime in enumerate(focuscrimes):
    focusCrimeDf = pd.DataFrame(df.groupby(['Category', 'Year']).count()
                             .filter(like = crime, axis=0)['PdId']).unstack(level=0)
    x1 = focusCrimeDf.plot(kind='bar', ax=axarr[i//2,i%2], title=crime, rot=0, legend=False)
    x2 = focusCrimeDf.plot(kind='bar', ax=axarr[i//2,i%2], title=crime, rot=0, legend=False)
